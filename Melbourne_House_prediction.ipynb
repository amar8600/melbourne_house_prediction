# %%
#import some necessary librairies

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline
import matplotlib.pyplot as plt  # Matlab-style plotting
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn #ignore annoying warning (from sklearn and seaborn)
from sklearn.model_selection import train_test_split

from scipy import stats
from scipy.stats import norm, skew #for some statistics


pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x)) #Limiting floats output to 3 decimal points
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()



from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import metrics

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('/content/cleaned_melbourn_housing_data.csv')

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bathroom', 'Car', 'Landsize',
#        'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname',
#        'Propertycount'],
#       dtype='object')

# %%
a = np.array(df.Price) # First need to convert to array 
house_all1 = a.reshape(-1,1) # Then reshape the data

# %%
df1 = pd.DataFrame(scaler.fit_transform(house_all1),columns  = ['Price'])
df = df.drop('Price',axis = 1)
df = pd.concat([df,df1],axis = 1)

# %%
df
# Out:
#                    Suburb              Address  ...  Propertycount Price
# 0              Abbotsford         85 Turner St  ...           4019 0.126
# 1              Abbotsford      25 Bloomburg St  ...           4019 0.085
# 2              Abbotsford         5 Charles St  ...           4019 0.124
# 3              Abbotsford     40 Federation La  ...           4019 0.069
# 4              Abbotsford          55a Park St  ...           4019 0.136
# 5              Abbotsford       129 Charles St  ...           4019 0.077
# 6              Abbotsford         124 Yarra St  ...           4019 0.161
# 7              Abbotsford        98 Charles St  ...           4019 0.140
# 8              Abbotsford   6/241 Nicholson St  ...           4019 0.019
# 9              Abbotsford        10 Valiant St  ...           4019 0.091
# 10             Abbotsford   411/8 Grosvenor St  ...           4019 0.055
# 11             Abbotsford      40 Nicholson St  ...           4019 0.114
# 12             Abbotsford  123/56 Nicholson St  ...           4019 0.060
# 13             Abbotsford        45 William St  ...           4019 0.098
# 14             Abbotsford   7/20 Abbotsford St  ...           4019 0.032
# 15             Abbotsford        16 William St  ...           4019 0.110
# 16             Abbotsford          42 Henry St  ...           4019 0.100
# 17             Abbotsford          78 Yarra St  ...           4019 0.098
# 18             Abbotsford     196 Nicholson St  ...           4019 0.078
# 19             Abbotsford        42 Valiant St  ...           4019 0.072
# 20             Abbotsford      3/72 Charles St  ...           4019 0.112
# 21             Abbotsford   13/11 Nicholson St  ...           4019 0.073
# 22             Abbotsford  138/56 Nicholson St  ...           4019 0.090
# 23             Abbotsford   6/219 Nicholson St  ...           4019 0.037
# 24             Abbotsford       52a William St  ...           4019 0.091
# 25             Abbotsford           49 Park St  ...           4019 0.111
# 26             Abbotsford   5/20 Abbotsford St  ...           4019 0.031
# 27             Abbotsford     48 Abbotsford St  ...           4019 0.123
# 28             Abbotsford  116/56 Nicholson St  ...           4019 0.033
# 29             Abbotsford          159 Park St  ...           4019 0.094
# ...                   ...                  ...  ...            ...   ...
# 20282            Wantirna       35 Ainsdale Av  ...           5424 0.060
# 20283            Wantirna     454 Mountain Hwy  ...           5424 0.061
# 20284          Warranwood      17 Tanbridge Wy  ...           1595 0.087
# 20285            Watsonia     292 Greenwood Dr  ...           2329 0.059
# 20286            Watsonia        32 Kenmare St  ...           2329 0.068
# 20287      Watsonia North          27 Byrne Cr  ...           1442 0.063
# 20288      Watsonia North        54 Sellars St  ...           1442 0.051
# 20289            Werribee       48 Conquest Dr  ...          16166 0.054
# 20290            Werribee          9 Parker St  ...          16166 0.072
# 20291            Werribee          27 Sinns Av  ...          16166 0.050
# 20292            Werribee      34 Westleigh Dr  ...          16166 0.066
# 20293      Werribee South         105 Robbs Rd  ...            821 0.050
# 20294      West Footscray        510 Barkly St  ...           5058 0.067
# 20295      West Footscray         13 Barton St  ...           5058 0.091
# 20296      West Footscray          30 Gwelo St  ...           5058 0.073
# 20297      West Melbourne       122 Railway Pl  ...           2230 0.096
# 20298         Westmeadows        35 Arnside Cr  ...           2474 0.053
# 20299       Wheelers Hill     45 Chancellor Dr  ...           7392 0.077
# 20300       Wheelers Hill          9 Walden Av  ...           7392 0.118
# 20301        Williamstown      13 Kingshott Cl  ...           6380 0.174
# 20302        Williamstown        5 Thompson St  ...           6380 0.077
# 20303  Williamstown North          32 Edina St  ...            802 0.067
# 20304             Wollert           10 Alma Rd  ...           2940 0.049
# 20305             Wollert      27 Birchmore Rd  ...           2940 0.037
# 20306             Wollert        16 Gunther Wy  ...           2940 0.048
# 20307             Wollert      35 Kingscote Wy  ...           2940 0.044
# 20308          Yarraville          13 Burns St  ...           6543 0.126
# 20309          Yarraville        29A Murray St  ...           6543 0.072
# 20310          Yarraville       147A Severn St  ...           6543 0.056
# 20311          Yarraville     3 Tarrengower St  ...           6543 0.084
#
# [20312 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bathroom         0
# Car              0
# Landsize         0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# Price            0
# dtype: int64

# %%
df
# Out:
#                    Suburb  ... Propertycount
# 0              Abbotsford  ...          4019
# 1              Abbotsford  ...          4019
# 2              Abbotsford  ...          4019
# 3              Abbotsford  ...          4019
# 4              Abbotsford  ...          4019
# 5              Abbotsford  ...          4019
# 6              Abbotsford  ...          4019
# 7              Abbotsford  ...          4019
# 8              Abbotsford  ...          4019
# 9              Abbotsford  ...          4019
# 10             Abbotsford  ...          4019
# 11             Abbotsford  ...          4019
# 12             Abbotsford  ...          4019
# 13             Abbotsford  ...          4019
# 14             Abbotsford  ...          4019
# 15             Abbotsford  ...          4019
# 16             Abbotsford  ...          4019
# 17             Abbotsford  ...          4019
# 18             Abbotsford  ...          4019
# 19             Abbotsford  ...          4019
# 20             Abbotsford  ...          4019
# 21             Abbotsford  ...          4019
# 22             Abbotsford  ...          4019
# 23             Abbotsford  ...          4019
# 24             Abbotsford  ...          4019
# 25             Abbotsford  ...          4019
# 26             Abbotsford  ...          4019
# 27             Abbotsford  ...          4019
# 28             Abbotsford  ...          4019
# 29             Abbotsford  ...          4019
# ...                   ...  ...           ...
# 20282            Wantirna  ...          5424
# 20283            Wantirna  ...          5424
# 20284          Warranwood  ...          1595
# 20285            Watsonia  ...          2329
# 20286            Watsonia  ...          2329
# 20287      Watsonia North  ...          1442
# 20288      Watsonia North  ...          1442
# 20289            Werribee  ...         16166
# 20290            Werribee  ...         16166
# 20291            Werribee  ...         16166
# 20292            Werribee  ...         16166
# 20293      Werribee South  ...           821
# 20294      West Footscray  ...          5058
# 20295      West Footscray  ...          5058
# 20296      West Footscray  ...          5058
# 20297      West Melbourne  ...          2230
# 20298         Westmeadows  ...          2474
# 20299       Wheelers Hill  ...          7392
# 20300       Wheelers Hill  ...          7392
# 20301        Williamstown  ...          6380
# 20302        Williamstown  ...          6380
# 20303  Williamstown North  ...           802
# 20304             Wollert  ...          2940
# 20305             Wollert  ...          2940
# 20306             Wollert  ...          2940
# 20307             Wollert  ...          2940
# 20308          Yarraville  ...          6543
# 20309          Yarraville  ...          6543
# 20310          Yarraville  ...          6543
# 20311          Yarraville  ...          6543
#
# [20312 rows x 17 columns]

# %%
imp = SimpleImputer(strategy = 'mean')

#Bathroom
imp.fit(df[['Bathroom']])
df['Bathroom'] = imp.transform(df[['Bathroom']]).ravel()
#Car
imp.fit(df[['Car']])
df['Car'] = imp.transform(df[['Car']]).ravel()
#Landsize
imp.fit(df[['Landsize']])
df['Landsize'] = imp.transform(df[['Landsize']]).ravel()
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bathroom         0
# Car              0
# Landsize         0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# Price            0
# dtype: int64

# %%
str(df.loc[1,['Address']].values)
# Out:
# "['25 Bloomburg St']"

# %%
import re
a = re.split('\s', str(df.loc[1,['Address']].values))

# %%
b = a[1:]
type(b)

c = ' '.join(b)
c

def street_name(addr):
    a = re.split('\s', addr)
    b = a[1:]
    c = ' '.join(b)
    return c

# %%
df['Street'] = df['Address'].apply(street_name)
df['Street'].tail(20)
# Out:
# 20292      Westleigh Dr
# 20293          Robbs Rd
# 20294         Barkly St
# 20295         Barton St
# 20296          Gwelo St
# 20297        Railway Pl
# 20298        Arnside Cr
# 20299     Chancellor Dr
# 20300         Walden Av
# 20301      Kingshott Cl
# 20302       Thompson St
# 20303          Edina St
# 20304           Alma Rd
# 20305      Birchmore Rd
# 20306        Gunther Wy
# 20307      Kingscote Wy
# 20308          Burns St
# 20309         Murray St
# 20310         Severn St
# 20311    Tarrengower St
# Name: Street, dtype: object

# %%
df_cleaned = df.copy()
df_cleaned['Street_Suburb'] = df_cleaned['Street']+'-'+df_cleaned['Suburb']
df_cleaned['Street_Suburb'].head(10)
# Out:
# 0        Turner St-Abbotsford
# 1     Bloomburg St-Abbotsford
# 2       Charles St-Abbotsford
# 3    Federation La-Abbotsford
# 4          Park St-Abbotsford
# 5       Charles St-Abbotsford
# 6         Yarra St-Abbotsford
# 7       Charles St-Abbotsford
# 8     Nicholson St-Abbotsford
# 9       Valiant St-Abbotsford
# Name: Street_Suburb, dtype: object

# %%
categories = ['Postcode', 'Street_Suburb','Type', 'CouncilArea', 'Method','Suburb', 'SellerG', 'Regionname']

for i in categories:
    df_cleaned[i+'_code'] = df_cleaned[i].astype('category').cat.codes


df_cleaned.head(10)
# Out:
#        Suburb             Address  ...  SellerG_code Regionname_code
# 0  Abbotsford        85 Turner St  ...            27               2
# 1  Abbotsford     25 Bloomburg St  ...            27               2
# 2  Abbotsford        5 Charles St  ...            27               2
# 3  Abbotsford    40 Federation La  ...            27               2
# 4  Abbotsford         55a Park St  ...           191               2
# 5  Abbotsford      129 Charles St  ...           128               2
# 6  Abbotsford        124 Yarra St  ...           191               2
# 7  Abbotsford       98 Charles St  ...           191               2
# 8  Abbotsford  6/241 Nicholson St  ...            27               2
# 9  Abbotsford       10 Valiant St  ...            27               2
#
# [10 rows x 28 columns]

# %%
df_train = df_cleaned.drop(categories, axis = 1)
df_train = df_train.drop(['Address', 'Street'], axis = 1)
df_train['Date'] = df_train['Date'].apply(pd.Timestamp)

#Converting Dates as days from 1st of January 2016 and dropping Date column
df_train['DaysFromJan2016']= df_train['Date']-pd.Timestamp('01-01-2016')
df_train['DaysFromJan2016']= df_train['DaysFromJan2016'].dt.days
df_train = df_train.drop('Date', axis = 1)
df_train.head()
# Out:
#    Rooms  Distance  Bathroom  ...  SellerG_code  Regionname_code  DaysFromJan2016
# 0      2     2.500     1.000  ...            27                2               71
# 1      2     2.500     1.000  ...            27                2               92
# 2      3     2.500     2.000  ...            27                2              458
# 3      3     2.500     2.000  ...            27                2              458
# 4      4     2.500     1.000  ...           191                2               96
#
# [5 rows x 18 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df_train.drop('Price', axis = 1), df_train['Price'], test_size = 0.3, random_state = 100)

# %% [markdown]
# <h1 id="Model-Building">Model Building<a class="anchor-link" href="#Model-Building">¶</a></h1><hr/>
# <p><img src="https://slideplayer.com/slide/15204316/92/images/1/What+is+Regression+Analysis.jpg"/></p>

# %% [markdown]
# ##1. Xgboost

# %% [markdown]
# #### For train eval

# %%
from xgboost.sklearn import XGBRegressor
model = XGBRegressor(objective="reg:linear", random_state=42) 
t0  = time.time()
model.fit(X_train, y_train)
print ("fitting time:", round(time.time()-t0, 3), "s")
# Out:
# [07:20:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# fitting time: 1.163 s

# %%
y_pred = model.predict(X_test)

# %%
mse=metrics.mean_squared_error(y_test, y_pred)
mse
# Out:
# 0.0009123528875018723

# %% [markdown]
# #### For test eval

# %%
y_pred = model.predict(X_train)

# %%
mse=metrics.mean_squared_error(y_train, y_pred)
mse
# Out:
# 0.0007295402372793473

# %% [markdown]
# <h2 id="2.-Gradient-Boosting-Regression-model">2. Gradient Boosting Regression model<a class="anchor-link" href="#2.-Gradient-Boosting-Regression-model">¶</a></h2><hr/>

# %% [markdown]
# #### For train mse

# %%
import time
# Initiate max R^2 score
max_r2 = 0

# Create Gradient Boosting Regression model that iterates through learning rates 
for i in np.linspace(0.1, 1, 50):
    
    # Initiate model for learning rate i
    gbr = GradientBoostingRegressor(learning_rate = i)
    t0=time.time()
    gbr.fit(X_train, y_train)
    
    
    # Make prediction
    t1=time.time()
    y_pred = gbr.predict(X_test)
   
    
    # Return values for corresponding learning rate
    print ('For learning rate i: %0.2f' %i)
    print('Gradient Boosting Regression MAE: %0.5f'%metrics.mean_absolute_error(y_test,y_pred))
    print('Gradient Boosting MSE:%0.5f'%metrics.mean_squared_error(y_test,y_pred))
    print('Gradient Boosting RMSE:%0.5f'%np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
    print('Gradient Boosting R^2: %0.5f' %metrics.explained_variance_score(y_test,y_pred))
    print ("fitting time:", round(time.time()-t0, 3), "s")
    print ("predict time:", round(time.time()-t1, 3), "s")
    print ('---------------------------------')

    # If R^2 new maximum score, save score and the learning rate
    if metrics.explained_variance_score(y_test,y_pred) > max_r2:
        max_r2 = metrics.explained_variance_score(y_test,y_pred)
        max_i = i
        time1 = round(time.time()-t0, 3)
        y_pred_gbr = y_pred
        
        # Store Standard Error
        se_gbr = stats.sem(y_pred_gbr)

# Print maximum R^2 score and corresponding learning rate
print ('Max R^2 is: %0.5f' %max_r2, 'with learning rate: %0.2f' %max_i,'and fitting time with %0.3f s'%time1)
# Out:
# For learning rate i: 0.10
# Gradient Boosting Regression MAE: 0.01772
# Gradient Boosting MSE:0.00091
# Gradient Boosting RMSE:0.03025
# Gradient Boosting R^2: 0.74439
# fitting time: 1.374 s
# predict time: 0.018 s
# ---------------------------------
# For learning rate i: 0.12
# Gradient Boosting Regression MAE: 0.01746
# Gradient Boosting MSE:0.00088
# Gradient Boosting RMSE:0.02974
# Gradient Boosting R^2: 0.75282
# fitting time: 1.293 s
# predict time: 0.018 s
# ---------------------------------
# For learning rate i: 0.14
# Gradient Boosting Regression MAE: 0.01720
# Gradient Boosting MSE:0.00087
# Gradient Boosting RMSE:0.02949
# Gradient Boosting R^2: 0.75706
# fitting time: 1.291 s
# predict time: 0.018 s
# ---------------------------------
# For learning rate i: 0.16
# Gradient Boosting Regression MAE: 0.01715
# Gradient Boosting MSE:0.00086
# Gradient Boosting RMSE:0.02941
# Gradient Boosting R^2: 0.75836
# fitting time: 1.274 s
# predict time: 0.02 s
# ---------------------------------
# For learning rate i: 0.17
# Gradient Boosting Regression MAE: 0.01691
# Gradient Boosting MSE:0.00084
# Gradient Boosting RMSE:0.02902
# Gradient Boosting R^2: 0.76469
# fitting time: 1.274 s
# predict time: 0.017 s
# ---------------------------------
# For learning rate i: 0.19
# Gradient Boosting Regression MAE: 0.01715
# Gradient Boosting MSE:0.00086
# Gradient Boosting RMSE:0.02934
# Gradient Boosting R^2: 0.75947
# fitting time: 1.273 s
# predict time: 0.017 s
# ---------------------------------
# For learning rate i: 0.21
# Gradient Boosting Regression MAE: 0.01690
# Gradient Boosting MSE:0.00084
# Gradient Boosting RMSE:0.02891
# Gradient Boosting R^2: 0.76646
# fitting time: 1.25 s
# predict time: 0.017 s
# ---------------------------------
# For learning rate i: 0.23
# Gradient Boosting Regression MAE: 0.01694
# Gradient Boosting MSE:0.00082
# Gradient Boosting RMSE:0.02871
# Gradient Boosting R^2: 0.76977
# fitting time: 1.268 s
# predict time: 0.017 s
# ---------------------------------
# For learning rate i: 0.25
# Gradient Boosting Regression MAE: 0.01681
# Gradient Boosting MSE:0.00083
# Gradient Boosting RMSE:0.02873
# Gradient Boosting R^2: 0.76935
# fitting time: 1.258 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.27
# Gradient Boosting Regression MAE: 0.01687
# Gradient Boosting MSE:0.00083
# Gradient Boosting RMSE:0.02884
# Gradient Boosting R^2: 0.76759
# fitting time: 1.252 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.28
# Gradient Boosting Regression MAE: 0.01675
# Gradient Boosting MSE:0.00081
# Gradient Boosting RMSE:0.02854
# Gradient Boosting R^2: 0.77248
# fitting time: 1.255 s
# predict time: 0.017 s
# ---------------------------------
# For learning rate i: 0.30
# Gradient Boosting Regression MAE: 0.01665
# Gradient Boosting MSE:0.00082
# Gradient Boosting RMSE:0.02859
# Gradient Boosting R^2: 0.77172
# fitting time: 1.258 s
# predict time: 0.017 s
# ---------------------------------
# For learning rate i: 0.32
# Gradient Boosting Regression MAE: 0.01660
# Gradient Boosting MSE:0.00081
# Gradient Boosting RMSE:0.02842
# Gradient Boosting R^2: 0.77445
# fitting time: 1.274 s
# predict time: 0.017 s
# ---------------------------------
# For learning rate i: 0.34
# Gradient Boosting Regression MAE: 0.01695
# Gradient Boosting MSE:0.00083
# Gradient Boosting RMSE:0.02879
# Gradient Boosting R^2: 0.76840
# fitting time: 1.239 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.36
# Gradient Boosting Regression MAE: 0.01682
# Gradient Boosting MSE:0.00081
# Gradient Boosting RMSE:0.02852
# Gradient Boosting R^2: 0.77273
# fitting time: 1.241 s
# predict time: 0.018 s
# ---------------------------------
# For learning rate i: 0.38
# Gradient Boosting Regression MAE: 0.01694
# Gradient Boosting MSE:0.00083
# Gradient Boosting RMSE:0.02878
# Gradient Boosting R^2: 0.76866
# fitting time: 1.253 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.39
# Gradient Boosting Regression MAE: 0.01693
# Gradient Boosting MSE:0.00084
# Gradient Boosting RMSE:0.02894
# Gradient Boosting R^2: 0.76607
# fitting time: 1.245 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.41
# Gradient Boosting Regression MAE: 0.01690
# Gradient Boosting MSE:0.00083
# Gradient Boosting RMSE:0.02889
# Gradient Boosting R^2: 0.76693
# fitting time: 1.282 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.43
# Gradient Boosting Regression MAE: 0.01678
# Gradient Boosting MSE:0.00078
# Gradient Boosting RMSE:0.02795
# Gradient Boosting R^2: 0.78183
# fitting time: 1.219 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.45
# Gradient Boosting Regression MAE: 0.01690
# Gradient Boosting MSE:0.00083
# Gradient Boosting RMSE:0.02876
# Gradient Boosting R^2: 0.76889
# fitting time: 1.251 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.47
# Gradient Boosting Regression MAE: 0.01710
# Gradient Boosting MSE:0.00085
# Gradient Boosting RMSE:0.02919
# Gradient Boosting R^2: 0.76194
# fitting time: 1.219 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.49
# Gradient Boosting Regression MAE: 0.01708
# Gradient Boosting MSE:0.00083
# Gradient Boosting RMSE:0.02873
# Gradient Boosting R^2: 0.76938
# fitting time: 1.259 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.50
# Gradient Boosting Regression MAE: 0.01700
# Gradient Boosting MSE:0.00084
# Gradient Boosting RMSE:0.02896
# Gradient Boosting R^2: 0.76574
# fitting time: 1.261 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.52
# Gradient Boosting Regression MAE: 0.01713
# Gradient Boosting MSE:0.00085
# Gradient Boosting RMSE:0.02919
# Gradient Boosting R^2: 0.76195
# fitting time: 1.213 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.54
# Gradient Boosting Regression MAE: 0.01721
# Gradient Boosting MSE:0.00089
# Gradient Boosting RMSE:0.02988
# Gradient Boosting R^2: 0.75050
# fitting time: 1.263 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.56
# Gradient Boosting Regression MAE: 0.01718
# Gradient Boosting MSE:0.00088
# Gradient Boosting RMSE:0.02958
# Gradient Boosting R^2: 0.75552
# fitting time: 1.245 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.58
# Gradient Boosting Regression MAE: 0.01741
# Gradient Boosting MSE:0.00086
# Gradient Boosting RMSE:0.02939
# Gradient Boosting R^2: 0.75881
# fitting time: 1.244 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.60
# Gradient Boosting Regression MAE: 0.01747
# Gradient Boosting MSE:0.00088
# Gradient Boosting RMSE:0.02960
# Gradient Boosting R^2: 0.75520
# fitting time: 1.274 s
# predict time: 0.019 s
# ---------------------------------
# For learning rate i: 0.61
# Gradient Boosting Regression MAE: 0.01728
# Gradient Boosting MSE:0.00082
# Gradient Boosting RMSE:0.02869
# Gradient Boosting R^2: 0.77004
# fitting time: 1.225 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.63
# Gradient Boosting Regression MAE: 0.01765
# Gradient Boosting MSE:0.00093
# Gradient Boosting RMSE:0.03053
# Gradient Boosting R^2: 0.73967
# fitting time: 1.244 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.65
# Gradient Boosting Regression MAE: 0.01758
# Gradient Boosting MSE:0.00093
# Gradient Boosting RMSE:0.03045
# Gradient Boosting R^2: 0.74087
# fitting time: 1.263 s
# predict time: 0.017 s
# ---------------------------------
# For learning rate i: 0.67
# Gradient Boosting Regression MAE: 0.01732
# Gradient Boosting MSE:0.00082
# Gradient Boosting RMSE:0.02865
# Gradient Boosting R^2: 0.77068
# fitting time: 1.236 s
# predict time: 0.015 s
# ---------------------------------
# For learning rate i: 0.69
# Gradient Boosting Regression MAE: 0.01756
# Gradient Boosting MSE:0.00087
# Gradient Boosting RMSE:0.02948
# Gradient Boosting R^2: 0.75709
# fitting time: 1.286 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.71
# Gradient Boosting Regression MAE: 0.01781
# Gradient Boosting MSE:0.00087
# Gradient Boosting RMSE:0.02958
# Gradient Boosting R^2: 0.75560
# fitting time: 1.278 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.72
# Gradient Boosting Regression MAE: 0.01738
# Gradient Boosting MSE:0.00083
# Gradient Boosting RMSE:0.02882
# Gradient Boosting R^2: 0.76815
# fitting time: 1.261 s
# predict time: 0.017 s
# ---------------------------------
# For learning rate i: 0.74
# Gradient Boosting Regression MAE: 0.01750
# Gradient Boosting MSE:0.00083
# Gradient Boosting RMSE:0.02889
# Gradient Boosting R^2: 0.76691
# fitting time: 1.298 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.76
# Gradient Boosting Regression MAE: 0.01745
# Gradient Boosting MSE:0.00082
# Gradient Boosting RMSE:0.02871
# Gradient Boosting R^2: 0.76986
# fitting time: 1.272 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.78
# Gradient Boosting Regression MAE: 0.01826
# Gradient Boosting MSE:0.00097
# Gradient Boosting RMSE:0.03113
# Gradient Boosting R^2: 0.72918
# fitting time: 1.251 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.80
# Gradient Boosting Regression MAE: 0.01792
# Gradient Boosting MSE:0.00084
# Gradient Boosting RMSE:0.02894
# Gradient Boosting R^2: 0.76610
# fitting time: 1.287 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.82
# Gradient Boosting Regression MAE: 0.01794
# Gradient Boosting MSE:0.00087
# Gradient Boosting RMSE:0.02948
# Gradient Boosting R^2: 0.75724
# fitting time: 1.256 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.83
# Gradient Boosting Regression MAE: 0.01821
# Gradient Boosting MSE:0.00091
# Gradient Boosting RMSE:0.03016
# Gradient Boosting R^2: 0.74583
# fitting time: 1.273 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.85
# Gradient Boosting Regression MAE: 0.01817
# Gradient Boosting MSE:0.00090
# Gradient Boosting RMSE:0.03002
# Gradient Boosting R^2: 0.74822
# fitting time: 1.272 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.87
# Gradient Boosting Regression MAE: 0.01851
# Gradient Boosting MSE:0.00096
# Gradient Boosting RMSE:0.03095
# Gradient Boosting R^2: 0.73236
# fitting time: 1.295 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.89
# Gradient Boosting Regression MAE: 0.01803
# Gradient Boosting MSE:0.00088
# Gradient Boosting RMSE:0.02960
# Gradient Boosting R^2: 0.75528
# fitting time: 1.27 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.91
# Gradient Boosting Regression MAE: 0.01839
# Gradient Boosting MSE:0.00089
# Gradient Boosting RMSE:0.02981
# Gradient Boosting R^2: 0.75168
# fitting time: 1.275 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.93
# Gradient Boosting Regression MAE: 0.01863
# Gradient Boosting MSE:0.00094
# Gradient Boosting RMSE:0.03072
# Gradient Boosting R^2: 0.73633
# fitting time: 1.264 s
# predict time: 0.017 s
# ---------------------------------
# For learning rate i: 0.94
# Gradient Boosting Regression MAE: 0.01831
# Gradient Boosting MSE:0.00091
# Gradient Boosting RMSE:0.03019
# Gradient Boosting R^2: 0.74535
# fitting time: 1.254 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.96
# Gradient Boosting Regression MAE: 0.01815
# Gradient Boosting MSE:0.00086
# Gradient Boosting RMSE:0.02929
# Gradient Boosting R^2: 0.76028
# fitting time: 1.24 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 0.98
# Gradient Boosting Regression MAE: 0.01877
# Gradient Boosting MSE:0.00095
# Gradient Boosting RMSE:0.03084
# Gradient Boosting R^2: 0.73439
# fitting time: 1.241 s
# predict time: 0.016 s
# ---------------------------------
# For learning rate i: 1.00
# Gradient Boosting Regression MAE: 0.01871
# Gradient Boosting MSE:0.00097
# Gradient Boosting RMSE:0.03111
# Gradient Boosting R^2: 0.72970
# fitting time: 1.267 s
# predict time: 0.016 s
# ---------------------------------
# Max R^2 is: 0.78183 with learning rate: 0.43 and fitting time with 1.222 s

# %% [markdown]
# #### For test mse

# %%
import time
# Initiate max R^2 score
max_r2 = 0

# Create Gradient Boosting Regression model that iterates through learning rates 
for i in np.linspace(0.1, 1, 50): 
    # Make prediction
    t1=time.time()
    y_pred = gbr.predict(X_train)
   
    
    # Return values for corresponding learning rate
    print ('For learning rate i: %0.2f' %i)
    print('Gradient Boosting Regression MAE: %0.5f'%metrics.mean_absolute_error(y_train,y_pred))
    print('Gradient Boosting MSE:%0.5f'%metrics.mean_squared_error(y_train,y_pred))
    print('Gradient Boosting RMSE:%0.5f'%np.sqrt(metrics.mean_squared_error(y_train,y_pred)))
    print('Gradient Boosting R^2: %0.5f' %metrics.explained_variance_score(y_train,y_pred))
    print ("predict time:", round(time.time()-t1, 3), "s")
    print ('---------------------------------')

    # If R^2 new maximum score, save score and the learning rate
    if metrics.explained_variance_score(y_train,y_pred) > max_r2:
        max_r2 = metrics.explained_variance_score(y_train,y_pred)
        max_i = i
        y_pred_gbr = y_pred
        
        # Store Standard Error
        se_gbr = stats.sem(y_pred_gbr)

# Print maximum R^2 score and corresponding learning rate
print ('Max R^2 is: %0.5f' %max_r2, 'with learning rate: %0.2f' %max_i)
# Out:
# For learning rate i: 0.10
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.036 s
# ---------------------------------
# For learning rate i: 0.12
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.14
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.16
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.17
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.031 s
# ---------------------------------
# For learning rate i: 0.19
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.034 s
# ---------------------------------
# For learning rate i: 0.21
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.23
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.034 s
# ---------------------------------
# For learning rate i: 0.25
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.27
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.027 s
# ---------------------------------
# For learning rate i: 0.28
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.029 s
# ---------------------------------
# For learning rate i: 0.30
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.32
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.027 s
# ---------------------------------
# For learning rate i: 0.34
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.027 s
# ---------------------------------
# For learning rate i: 0.36
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.033 s
# ---------------------------------
# For learning rate i: 0.38
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.39
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.034 s
# ---------------------------------
# For learning rate i: 0.41
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.029 s
# ---------------------------------
# For learning rate i: 0.43
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.45
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.029 s
# ---------------------------------
# For learning rate i: 0.47
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.49
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.033 s
# ---------------------------------
# For learning rate i: 0.50
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.027 s
# ---------------------------------
# For learning rate i: 0.52
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.027 s
# ---------------------------------
# For learning rate i: 0.54
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.027 s
# ---------------------------------
# For learning rate i: 0.56
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.027 s
# ---------------------------------
# For learning rate i: 0.58
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.027 s
# ---------------------------------
# For learning rate i: 0.60
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.027 s
# ---------------------------------
# For learning rate i: 0.61
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.63
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.031 s
# ---------------------------------
# For learning rate i: 0.65
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.027 s
# ---------------------------------
# For learning rate i: 0.67
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.69
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.03 s
# ---------------------------------
# For learning rate i: 0.71
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.72
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.74
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.029 s
# ---------------------------------
# For learning rate i: 0.76
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.034 s
# ---------------------------------
# For learning rate i: 0.78
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.80
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.82
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.83
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.85
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.87
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.89
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.029 s
# ---------------------------------
# For learning rate i: 0.91
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.033 s
# ---------------------------------
# For learning rate i: 0.93
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.03 s
# ---------------------------------
# For learning rate i: 0.94
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.96
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 0.98
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# For learning rate i: 1.00
# Gradient Boosting Regression MAE: 0.01456
# Gradient Boosting MSE:0.00046
# Gradient Boosting RMSE:0.02137
# Gradient Boosting R^2: 0.86715
# predict time: 0.028 s
# ---------------------------------
# Max R^2 is: 0.86715 with learning rate: 0.10

# %% [markdown]
# <h2 id="3.-Linear-Regression-model">3. Linear Regression model<a class="anchor-link" href="#3.-Linear-Regression-model">¶</a></h2><hr/>

# %% [markdown]
# #### For train mse

# %%
from sklearn.linear_model import LinearRegression
# Initialise Linear Regression model
lr = LinearRegression()
t0=time.time()
lr.fit(X_train, y_train)

# Make Prediction
t1=time.time()
y_pred_lr = lr.predict(X_test)

# Return Results
print('Linear Regression MAE: %0.5f'%metrics.mean_absolute_error(y_test,y_pred_lr))
print('Linear Regression MSE:%0.5f'%metrics.mean_squared_error(y_test,y_pred_lr))
print('Linear Regression RMSE:%0.5f'%np.sqrt(metrics.mean_squared_error(y_test,y_pred_lr)))
print('Linear Regression R^2: %0.5f' %metrics.explained_variance_score(y_test,y_pred_lr))
print ("fitting time:", round(time.time()-t0, 3), "s")
print ("predict time:", round(time.time()-t1, 3), "s")

# Store Standard Error
se_lr = stats.sem(y_pred_lr)
# Out:
# Linear Regression MAE: 0.02549
# Linear Regression MSE:0.00155
# Linear Regression RMSE:0.03937
# Linear Regression R^2: 0.56683
# fitting time: 0.028 s
# predict time: 0.008 s

# %% [markdown]
# #### For test mse

# %%
# Make Prediction
t1=time.time()
y_pred_lr = lr.predict(X_train)

# Return Results
print('Linear Regression MAE: %0.5f'%metrics.mean_absolute_error(y_train,y_pred_lr))
print('Linear Regression MSE:%0.5f'%metrics.mean_squared_error(y_train,y_pred_lr))
print('Linear Regression RMSE:%0.5f'%np.sqrt(metrics.mean_squared_error(y_train,y_pred_lr)))
print('Linear Regression R^2: %0.5f' %metrics.explained_variance_score(y_train,y_pred_lr))
print ("predict time:", round(time.time()-t1, 3), "s")

# Store Standard Error
se_lr = stats.sem(y_pred_lr)
# Out:
# Linear Regression MAE: 0.02504
# Linear Regression MSE:0.00144
# Linear Regression RMSE:0.03790
# Linear Regression R^2: 0.58186
# predict time: 0.014 s

# %% [markdown]
# <h2 id="4.-Lasso-Regression-model">4. Lasso Regression model<a class="anchor-link" href="#4.-Lasso-Regression-model">¶</a></h2><hr/>

# %% [markdown]
# #### For Train mse

# %%
# Initialise Lasso Regression model
lcv = LassoCV()
t0=time.time()
lcv.fit(X_train, y_train)

# Make Prediction
t1=time.time()
y_pred_lcv = lcv.predict(X_test)

# Return Results
print('Lasso Regression MAE: %0.5f'%metrics.mean_absolute_error(y_test,y_pred_lcv))
print('Lasso Regression MSE:%0.5f'%metrics.mean_squared_error(y_test,y_pred_lcv))
print('Lasso Regression RMSE:%0.5f'%np.sqrt(metrics.mean_squared_error(y_test,y_pred_lcv)))
print('Lasso Regression R^2: %0.5f' %metrics.explained_variance_score(y_test,y_pred_lcv))
print ("fitting time:", round(time.time()-t0, 3), "s")
print ("predict time:", round(time.time()-t1, 3), "s")

se_lcv = stats.sem(y_pred_lcv)
# Out:
# Lasso Regression MAE: 0.03027
# Lasso Regression MSE:0.00216
# Lasso Regression RMSE:0.04650
# Lasso Regression R^2: 0.39618
# fitting time: 0.197 s
# predict time: 0.007 s

# %% [markdown]
# #### For test mse

# %%
# Make Prediction
t1=time.time()
y_pred_lcv = lcv.predict(X_train)

# Return Results
print('Lasso Regression MAE: %0.5f'%metrics.mean_absolute_error(y_train,y_pred_lcv))
print('Lasso Regression MSE:%0.5f'%metrics.mean_squared_error(y_train,y_pred_lcv))
print('Lasso Regression RMSE:%0.5f'%np.sqrt(metrics.mean_squared_error(y_train,y_pred_lcv)))
print('Lasso Regression R^2: %0.5f' %metrics.explained_variance_score(y_train,y_pred_lcv))
print ("fitting time:", round(time.time()-t0, 3), "s")
print ("predict time:", round(time.time()-t1, 3), "s")

se_lcv = stats.sem(y_pred_lcv)
# Out:
# Lasso Regression MAE: 0.02988
# Lasso Regression MSE:0.00208
# Lasso Regression RMSE:0.04559
# Lasso Regression R^2: 0.39519
# fitting time: 22.558 s
# predict time: 0.023 s

# %% [markdown]
# <h2 id="5.-Random-Forest-Model">5. Random Forest Model<a class="anchor-link" href="#5.-Random-Forest-Model">¶</a></h2><hr/>

# %% [markdown]
# #### For train mse

# %%
# Initialise Max R^2 variable 
max_r2 = 0

# Create Random Forest Model that iterates between 64 --> 128 trees
for n_trees in range (119, 129):
    hi
    # Initiate model for value n_tree
    rfr = RandomForestRegressor(n_estimators=n_trees, n_jobs=-1)
    t0=time.time()
    rfr.fit(X_train, y_train)
    
    # Make prediction for n_tree sized model
    t1=time.time()
    y_pred = rfr.predict(X_test)
    
    # Store Standard Error
    rfr_sem = stats.sem (y_pred)
    
    # Print Results
    print('For a Random Forest with', n_trees, 'trees in total:')
    print('MAE: %0.5f'%metrics.mean_absolute_error(y_test,y_pred))
    print('MSE:%0.5f'%metrics.mean_squared_error(y_test,y_pred))
    print('RMSE:%0.5f'%np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
    print('R^2: %0.5f' %metrics.explained_variance_score(y_test,y_pred))
    print ("fitting time:", round(time.time()-t0, 3), "s")
    print ("predict time:", round(time.time()-t1, 3), "s")
    print('--------------------------------------')
    
    # If new R^2 the max, store it for reference
    if metrics.explained_variance_score(y_test,y_pred) > max_r2:
        max_r2 = metrics.explained_variance_score(y_test,y_pred)
        max_n_trees = n_trees
        max_rfr_sem = rfr_sem
        y_pred_rfr= y_pred
        
        # Store Standard Error
        se_rfr = stats.sem(y_pred_rfr)

# Return max R^2 and corresponding amount of trees in forest
print ('Max R^2 is: %0.5f' %max_r2, 'at', max_n_trees, 'trees')
# Out:
# For a Random Forest with 119 trees in total:
# MAE: 0.01554
# MSE:0.00075
# RMSE:0.02736
# R^2: 0.79100
# fitting time: 10.803 s
# predict time: 0.21 s
# --------------------------------------
# For a Random Forest with 120 trees in total:
# MAE: 0.01552
# MSE:0.00074
# RMSE:0.02721
# R^2: 0.79324
# fitting time: 10.894 s
# predict time: 0.211 s
# --------------------------------------
# For a Random Forest with 121 trees in total:
# MAE: 0.01551
# MSE:0.00074
# RMSE:0.02727
# R^2: 0.79224
# fitting time: 10.993 s
# predict time: 0.209 s
# --------------------------------------
# For a Random Forest with 122 trees in total:
# MAE: 0.01559
# MSE:0.00075
# RMSE:0.02735
# R^2: 0.79110
# fitting time: 11.091 s
# predict time: 0.211 s
# --------------------------------------
# For a Random Forest with 123 trees in total:
# MAE: 0.01552
# MSE:0.00074
# RMSE:0.02722
# R^2: 0.79310
# fitting time: 11.191 s
# predict time: 0.21 s
# --------------------------------------
# For a Random Forest with 124 trees in total:
# MAE: 0.01554
# MSE:0.00074
# RMSE:0.02726
# R^2: 0.79239
# fitting time: 11.292 s
# predict time: 0.21 s
# --------------------------------------
# For a Random Forest with 125 trees in total:
# MAE: 0.01556
# MSE:0.00075
# RMSE:0.02734
# R^2: 0.79120
# fitting time: 11.298 s
# predict time: 0.211 s
# --------------------------------------
# For a Random Forest with 126 trees in total:
# MAE: 0.01551
# MSE:0.00074
# RMSE:0.02726
# R^2: 0.79239
# fitting time: 11.494 s
# predict time: 0.209 s
# --------------------------------------
# For a Random Forest with 127 trees in total:
# MAE: 0.01558
# MSE:0.00075
# RMSE:0.02735
# R^2: 0.79103
# fitting time: 11.396 s
# predict time: 0.211 s
# --------------------------------------
# For a Random Forest with 128 trees in total:
# MAE: 0.01554
# MSE:0.00074
# RMSE:0.02724
# R^2: 0.79270
# fitting time: 11.594 s
# predict time: 0.21 s
# --------------------------------------
# Max R^2 is: 0.79324 at 120 trees

# %% [markdown]
# #### For test mse

# %%
# Initialise Max R^2 variable 
max_r2 = 0

# Create Random Forest Model that iterates between 64 --> 128 trees
for n_trees in range (119, 129):
    
    # Make prediction for n_tree sized model
    t1=time.time()
    y_pred = rfr.predict(X_train)
    
    # Store Standard Error
    rfr_sem = stats.sem (y_pred)
    
    # Print Results
    print('For a Random Forest with', n_trees, 'trees in total:')
    print('MAE: %0.5f'%metrics.mean_absolute_error(y_train,y_pred))
    print('MSE:%0.5f'%metrics.mean_squared_error(y_train,y_pred))
    print('RMSE:%0.5f'%np.sqrt(metrics.mean_squared_error(y_train,y_pred)))
    print('R^2: %0.5f' %metrics.explained_variance_score(y_train,y_pred))
    print ("predict time:", round(time.time()-t1, 3), "s")
    print('--------------------------------------')
    
    # If new R^2 the max, store it for reference
    if metrics.explained_variance_score(y_train,y_pred) > max_r2:
        max_r2 = metrics.explained_variance_score(y_train,y_pred)
        max_n_trees = n_trees
        max_rfr_sem = rfr_sem
        y_pred_rfr= y_pred
        
        # Store Standard Error
        se_rfr = stats.sem(y_pred_rfr)

# Return max R^2 and corresponding amount of trees in forest
print ('Max R^2 is: %0.5f' %max_r2, 'at', max_n_trees, 'trees')
# Out:
# For a Random Forest with 119 trees in total:
# MAE: 0.00549
# MSE:0.00009
# RMSE:0.00959
# R^2: 0.97327
# predict time: 0.421 s
# --------------------------------------
# For a Random Forest with 120 trees in total:
# MAE: 0.00549
# MSE:0.00009
# RMSE:0.00959
# R^2: 0.97327
# predict time: 0.41 s
# --------------------------------------
# For a Random Forest with 121 trees in total:
# MAE: 0.00549
# MSE:0.00009
# RMSE:0.00959
# R^2: 0.97327
# predict time: 0.409 s
# --------------------------------------
# For a Random Forest with 122 trees in total:
# MAE: 0.00549
# MSE:0.00009
# RMSE:0.00959
# R^2: 0.97327
# predict time: 0.41 s
# --------------------------------------
# For a Random Forest with 123 trees in total:
# MAE: 0.00549
# MSE:0.00009
# RMSE:0.00959
# R^2: 0.97327
# predict time: 0.41 s
# --------------------------------------
# For a Random Forest with 124 trees in total:
# MAE: 0.00549
# MSE:0.00009
# RMSE:0.00959
# R^2: 0.97327
# predict time: 0.41 s
# --------------------------------------
# For a Random Forest with 125 trees in total:
# MAE: 0.00549
# MSE:0.00009
# RMSE:0.00959
# R^2: 0.97327
# predict time: 0.409 s
# --------------------------------------
# For a Random Forest with 126 trees in total:
# MAE: 0.00549
# MSE:0.00009
# RMSE:0.00959
# R^2: 0.97327
# predict time: 0.41 s
# --------------------------------------
# For a Random Forest with 127 trees in total:
# MAE: 0.00549
# MSE:0.00009
# RMSE:0.00959
# R^2: 0.97327
# predict time: 0.409 s
# --------------------------------------
# For a Random Forest with 128 trees in total:
# MAE: 0.00549
# MSE:0.00009
# RMSE:0.00959
# R^2: 0.97327
# predict time: 0.41 s
# --------------------------------------
# Max R^2 is: 0.97327 at 119 trees

# %%
# !pip install tabletext
# Out:
# Collecting tabletext
#   Downloading https://files.pythonhosted.org/packages/ed/53/4152a8c71531d4b09eb34cfd7cd18f3764a988de4dc9039405f8182dddb7/tabletext-0.1.tar.gz
# Building wheels for collected packages: tabletext
#   Building wheel for tabletext (setup.py) ... done
#   Created wheel for tabletext: filename=tabletext-0.1-cp36-none-any.whl size=6026 sha256=1a5a985753ce71ef247285dbeaaebd6d2da299fc06d7c9c5d4cd7a0668f0e3ec
#   Stored in directory: /root/.cache/pip/wheels/63/15/d8/897b137f43975c4f5f49139be65fee6dbeab6a3f88c1838f66
# Successfully built tabletext
# Installing collected packages: tabletext
# Successfully installed tabletext-0.1

# %%
import tabletext

data = [['Models','Train. MSE','Eval. MSE','Eval. Ratio','fitting Time (in s)'],
        ['Linear Regression model',0.00155,0.00144,1,0.028],
        ['Xgboost',0.00091,0.00083,0.50,1.163],['Gradient Boosting Regression model',0.00078,0.00046,0.319,1.222],
        ['Lasso Regression model',0.00216,0.00208,1.44,0.197],['Random Forest Model',0.00073,0.00009,0.0625,10.893]
        ]

print("Linear regression will act as the baseline for model comparison.\n The evaluation ratio of each \
model is equal to its evaluation MSE divide to the \
evaluation MSE of Linear regression. \nThe smaller \
evaluation ratio, the higher accuracy of model’s \
prediction.\n")
print( tabletext.to_text(data))
# Out:
# Linear regression will act as the baseline for model comparison.
#  The evaluation ratio of each model is equal to its evaluation MSE divide to the evaluation MSE of Linear regression.
# The smaller evaluation ratio, the higher accuracy of model’s prediction.
#
# ┌────────────────────────────────────┬────────────┬───────────┬─────────────┬─────────────────────┐
# │ Models                             │ Train. MSE │ Eval. MSE │ Eval. Ratio │ fitting Time (in s) │
# ├────────────────────────────────────┼────────────┼───────────┼─────────────┼─────────────────────┤
# │ Linear Regression model            │    0.00155 │   0.00144 │           1 │               0.028 │
# ├────────────────────────────────────┼────────────┼───────────┼─────────────┼─────────────────────┤
# │ Xgboost                            │    0.00091 │   0.00083 │         0.5 │               1.163 │
# ├────────────────────────────────────┼────────────┼───────────┼─────────────┼─────────────────────┤
# │ Gradient Boosting Regression model │    0.00078 │   0.00046 │       0.319 │               1.222 │
# ├────────────────────────────────────┼────────────┼───────────┼─────────────┼─────────────────────┤
# │ Lasso Regression model             │    0.00216 │   0.00208 │        1.44 │               0.197 │
# ├────────────────────────────────────┼────────────┼───────────┼─────────────┼─────────────────────┤
# │ Random Forest Model                │    0.00073 │     9e-05 │      0.0625 │              10.893 │
# └────────────────────────────────────┴────────────┴───────────┴─────────────┴─────────────────────┘
